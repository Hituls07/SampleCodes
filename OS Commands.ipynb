# %%
import os

# %%
os.getcwd() # To get current directory
# Out:
# '/Users/hitulshah'

# %%
os.chdir('/Users/hitulshah') #To change directory

# %%
os.makedirs('OStesting/OStestingsub') #To make folder (can be multilevels)

# %%
os.listdir() #To list out all the files inside of directory
# Out:
# ['.Rhistory',
#  'Music',
#  '.condarc',
#  'Linear regression_HS.ipynb',
#  'Untitled1.ipynb',
#  '.DS_Store',
#  'MNIST Data.ipynb',
#  'titanic_submission_1.csv',
#  '.CFUserTextEncoding',
#  'DataUniverse',
#  'Untitled3.ipynb',
#  'Untitled.ipynb',
#  'Pictures',
#  'Codewars Two Fighters.ipynb',
#  'Untitled2.ipynb',
#  '.ipython',
#  'Geron Github',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'OStesting',
#  'Chapter3-3-Titanic Data.ipynb',
#  'seaborn-data',
#  'scikit_learn_data',
#  'Logistic Regression_HS.ipynb',
#  '.bash_sessions',
#  'Direction Codewars.ipynb',
#  'Tribonacci.ipynb',
#  'Public',
#  '.bash_profile-anaconda3.bak',
#  '.idlerc',
#  'OS Commands.ipynb',
#  '.anaconda',
#  'Movies',
#  'Applications',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  'Documents',
#  'Regression_R_Python.ipynb',
#  '.rstudio-desktop',
#  'Chapter3-1.MNIST Improvement.ipynb',
#  '.bash_profile',
#  'Chapter3-2-MNIST Data Augmentation.ipynb',
# ...

# %%
os.listdir('/Users/hitulshah/OStesting') #To open any folder and see list of files inside of it

# %%
os.rmdir('OStesting.txt') #To remove directories
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-0337e2987bed> in <module>()
# ----> 1 os.rmdir('OStesting.txt') #To remove directories
#
# FileNotFoundError: [Errno 2] No such file or directory: 'OStesting.txt'

# %%
#os.makedirs('Rename Testing')
os.rename( 'Rename Testing' , 'Test_rename') # To rename files

# %%
os.stat('Test_Rename') # To know stats about the file
# Out:
# os.stat_result(st_mode=16877, st_ino=3620642, st_dev=16777220, st_nlink=2, st_uid=501, st_gid=20, st_size=64, st_atime=1541231009, st_mtime=1541231009, st_ctime=1541231074)

# %%
from datetime import datetime
file_created = os.stat('Test_Rename').st_mtime 
print(datetime.fromtimestamp(file_created)) #Print Time on file created
# Out:
# 2018-11-03 00:43:29.082428

# %%
for dirpath ,dirname ,filename in os.walk('/Users/hitulshah/Downloads'):
    print(dirpath)
    print(dirname)
    print(filename)
    print() 
    
#Walk goes into three level. Directory path, dirname and filename. Above code is printing all files along with its path and directory name
# Out:
# /Users/hitulshah/Downloads
# ['Refactored_Py_DS_ML_Bootcamp-master', 'Catholic Health Initiatives, Jobs & Salary for Foreign Workers _ myvisajobs.com_files', 'Insurance Docs', 'flutter']
# ...

# %%
for dirnpath, dirname , filename in os.walk('/Users/hitulshah/Downloads'): 
    print(filename)
# Out:
# ['Resume_Hitul_Shah.docx', 'Resume_Hitul_Shah (1).docx', 'Catholic Health Initiatives, Jobs & Salary for Foreign Workers _ myvisajobs.com.html', 'Industrial_Engineer.docx', '18_65 PATIENTS - A-012019.xlsx', 'thank-you-for-advocating-for-children-in-poverty-in-india.jpg', '~$sume_Hitul_Shah.docx', 'V38N6p564.pdf', 'pycharm-professional-2018.2.4.dmg', '.DS_Store', 'Itinerary Details.pdf', 'UPS CampusShip - United States.pdf', '.localized', '8470d28a53164d8f4fa247ddca2716b6.jpg', 'HomeCredit_columns_description.csv', 'Understanding Evidence Basis for Control of Hypertension.pdf', '20181220 Ramblings of the Data Wranglers.docx', 'Cosmos.A.Space.Time.Odyssey.S01E06.720p.HDTV.X264-DIMENSION.mkv', 'launch.ica', 'ISLR Sixth Printing.pdf', 'launch (1).ica', '20190128 Ramblings of the Data Wranglers.docx', '~$sume_Hitul_Shah (1).docx', 'EAD.pdf', 'AdobeFlashPlayer.dmg', 'Agenda 1.21.19.docx', 'python-machine-learning-book-master.zip', 'tensorflow-safari-course-master.zip', 'pycharm-community-2
# ...

# %%
os.environ.get('HOME') #To open running enviromnet on this notebook
# Out:
# '/Users/hitulshah'

# %%
home = os.environ.get('HOME') 
print(os.path.join(home, 'note.txt')) #path.join helps to join paths with name 
new_file_path = os.path.join(home,'note.txt')
# Out:
# /Users/hitulshah/note.txt

# %%
with open(new_file_path,'a') as f:
    f.write('abc') #Open/ create (see open documentation) a file and write() function writes inside it

# %%
os.path.isdir('/Users/hitulshah/') #To check whether directory exists or not
# Out:
# True

# %%
os.path.exists(new_file_path) #Check whether file exists inside or not
# Out:
# True

# %%
os.path.basename(new_file_path) #Gives filename with extension
# Out:
# 'note'
